# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Running cells with 'Python 3.6.13 64-bit ('auto': conda)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n auto ipykernel --update-deps --force-reinstall'

# %%
# %cd /content/drive/MyDrive/Crawl_Facebook
# Out:
# /content/drive/MyDrive/Crawl_Facebook

# %%
# !pip install numpy pandas
# Out:
# Collecting numpy
#   Using cached numpy-1.19.5-cp36-cp36m-win_amd64.whl (13.2 MB)
# Collecting pandas
#   Downloading pandas-1.1.5-cp36-cp36m-win_amd64.whl (8.7 MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\phong\anaconda3\envs\auto\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2017.2
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
# Requirement already satisfied: six>=1.5 in c:\users\phong\anaconda3\envs\auto\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.19.5 pandas-1.1.5 pytz-2021.3

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# install chromium, its driver, and selenium
# !apt update -y
# !apt install chromium-chromedriver -y
# !pip install selenium
# !pip install helium
# !pip install free-proxy
# set options to be headless, ..
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
# open it, go to a website, and get results
wd = webdriver.Chrome('chromedriver',options=options)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from test import *
# from importlib.resources import contents
from pip import main
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
import os
from time import sleep
import json 
cookie = 'cookie: datr=zCl1YfSOcGf17m9dXXY7eSaB; sb=zg8HYr27z2Eze4zpOblULwod; dpr=1.25; locale=vi_VN; wd=1488x754; c_user=100078509210570; xs=2%3AdK7lsdMi8XwFoQ%3A2%3A1646105133%3A-1%3A-1; fr=0MRspGNSQYfr6Brep.AWWETuMAYWgC08UmlQDDNmoo6UM.BiHNcs.jK.AAA.0.0.BiHZJM.AWXjlK0yd7A; presence=C%7B%22t3%22%3A%5B%5D%2C%22utc3%22%3A1646105170400%2C%22v%22%3A1%7D'
driver = initDriver()
driver.get('https://touch.facebook.com/')
sleep(2)
loginFacebookByCookie(driver ,cookie)
sleep(2)
try:
    dsPost={}
    Id_List = getnumOfPost(driver, 'danphunhuantphcm')
    for idPost in Id_List:
      DS = getPoster(driver, idPost)
      dsPost[str(idPost)]= DS
    with open("danphunhuantphcm.json", "w",encoding="utf-8") as outfile:
        json.dump(dsPost, outfile, ensure_ascii=False)
    print('Success')
except Exception as e:
  print('Failed')
  print(e)
driver.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-d5e60e5778ad> in <module>
# ----> 1 from test import *
#       2 # from importlib.resources import contents
#       3 from pip import main
#       4 from selenium import webdriver
#       5 from selenium.webdriver.chrome.options import Options
#
# f:\Learning\Nghiên cứu khoa học\2021-2022\facebook-data-extraction\2 - Automation tools with IP hiding techniques\test.py in <module>
# ----> 1 from importlib.resources import contents
#       2 from pip import main
#       3 from selenium import webdriver
#       4 from selenium.webdriver.chrome.options import Options
#       5 from selenium.webdriver.support.ui import WebDriverWait
#
# ModuleNotFoundError: No module named 'importlib.resources'
