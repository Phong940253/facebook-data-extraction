# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from test import *
# from importlib.resources import contents
from pip import main
import os
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
import os
from time import sleep
import json 

# list file post
import glob
groupPost = glob.glob("data/*/*/*.json")
pagePost = glob.glob("data/*/*.json")
groupPagePost = groupPost + pagePost
listPostFile = []
for postFile in groupPagePost:
    listPostFile.append(postFile.split("\\")[-1].split(".")[0])

cookie = 'cookie: datr=zCl1YfSOcGf17m9dXXY7eSaB; sb=zg8HYr27z2Eze4zpOblULwod; dpr=1.25; locale=vi_VN; wd=1488x754; c_user=100078509210570; xs=2%3AdK7lsdMi8XwFoQ%3A2%3A1646105133%3A-1%3A-1; fr=0MRspGNSQYfr6Brep.AWWETuMAYWgC08UmlQDDNmoo6UM.BiHNcs.jK.AAA.0.0.BiHZJM.AWXjlK0yd7A; presence=C%7B%22t3%22%3A%5B%5D%2C%22utc3%22%3A1646105170400%2C%22v%22%3A1%7D'
driver = initDriver()
# driver.get('https://touch.facebook.com/')

namePage = [
  'groups/364997627165697',
  'nhung.truyen.ngan.hay',
  'danphunhuantphcm', 
  'nhatky',
  'vntravel',
  'rapphim',
  'KHTNCFS',
  'CodeLearnFanpage',
  'pagenaykhonghetrend',
  'chuyencuaem.page'
  ]

# sleep(2)
driver = loginFacebook(driver)
# loginFacebookByCookie(driver ,cookie)
sleep(4)
print("start crawl")
for page in namePage:
  try:
      dsPost = {}
      Id_List = getnumOfPost(driver, page)
      if not os.path.exists(f'data/{page}'):
        os.makedirs(f'data/{page}')
      for idPost in Id_List:
        if (idPost in listPostFile):
          continue
        DS = getPoster(driver, idPost)
        if DS is not None:
          with open(f'data/{page}/{idPost}.json', "w",encoding="utf-8") as outfile:
            json.dump(DS, outfile, ensure_ascii=False)
        # dsPost[str(idPost)]= DS
      print('Success')
  except Exception as e:
    print('Failed')
    print(e)
driver.close()
# Out:
# phong940258@gmail.com
# start crawl
# Srolling 0 time
# Srolling 1 time
# Srolling 2 time
# Srolling 3 time
# Srolling 4 time
# Srolling 5 time
# Srolling 6 time
# Srolling 7 time
# Srolling 8 time
# Srolling 9 time
# Srolling 10 time
# Srolling 11 time
# Srolling 12 time
# Srolling 13 time
# Srolling 14 time
# Srolling 15 time
# Srolling 16 time
# Srolling 17 time
# Srolling 18 time
# Srolling 19 time
# Srolling 20 time
# Srolling 21 time
# Srolling 22 time
# Srolling 23 time
# Srolling 24 time
# Srolling 25 time
# Srolling 26 time
# Srolling 27 time
# Srolling 28 time
# Srolling 29 time
# Srolling 30 time
# Srolling 31 time
# Srolling 32 time
# Srolling 33 time
# Srolling 34 time
# Srolling 35 time
# Srolling 36 time
# Srolling 37 time
# Srolling 38 time
# Srolling 39 time
# Srolling 40 time
# Srolling 41 time
# Srolling 42 time
# Srolling 43 time
# Srolling 44 time
# Srolling 45 time
# Srolling 46 time
# Srolling 47 time
# Srolling 48 time
# Srolling 49 time
# Srolling 50 time
# Srolling 51 time
# Srolling 52 time
# Đang lấy thông tin của post có ID là 1706149069717206
# 5
# Đang lấy thông tin của post có ID là 1786744978324281
# Click view more button 1 time
# Click view more button 2 time
# Click view more button 3 time
# Click view more button 4 time
# Click view more button 5 time
# Click view more button 6 time
# Click view more button 7 time
# Click view more button 8 time
# Click view more button 9 time
# Click view more button 10 time
# Click view more button 11 time
# Click view more button 12 time
# Click view more button 13 time
# Click view more button 14 time
# Click view more button 15 time
# Click view more button 16 time
# Click view more button 17 time
# Click view more button 18 time
# Click view more button 19 time
# Click view more button 20 time
# Click view more reply 3 element
# 6
# Comment của Justin Đặng này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Huỳnh Trung này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyen Tri này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 1786667011665411
# Click view more button 1 time
# Click view more button 2 time
# Click view more button 3 time
# Click view more button 4 time
# Click view more button 5 time
# Click view more button 6 time
# Click view more button 7 time
# Click view more button 8 time
# Click view more button 9 time
# Click view more button 10 time
# Click view more button 11 time
# Click view more button 12 time
# Click view more button 13 time
# Click view more button 14 time
# Click view more button 15 time
# Click view more button 16 time
# Click view more button 17 time
# Click view more button 18 time
# Click view more button 19 time
# Click view more button 20 time
# Click view more reply 4 element
# 10
# Comment của Hung Pham này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Pawn Erasil này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Duy này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trung Dũng này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 1781679028830876
# Click view more button 1 time
# Click view more button 2 time
# Click view more button 3 time
# Click view more button 4 time
# Click view more button 5 time
# Click view more button 6 time
# Click view more button 7 time
# Click view more button 8 time
# Click view more button 9 time
# Click view more button 10 time
# Click view more button 11 time
# Click view more button 12 time
# Click view more button 13 time
# Click view more button 14 time
# Click view more button 15 time
# Click view more button 16 time
# Click view more button 17 time
# Click view more button 18 time
# Click view more button 19 time
# Click view more button 20 time
# Click view more reply 1 element
# 8
# Comment của Triết Võ này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 1786068595058586
# Click view more button 1 time
# Click view more button 2 time
# Click view more button 3 time
# Click view more button 4 time
# Click view more button 5 time
# Click view more button 6 time
# Click view more button 7 time
# Click view more button 8 time
# Click view more button 9 time
# Click view more button 10 time
# Click view more button 11 time
# Click view more button 12 time
# Click view more button 13 time
# Click view more button 14 time
# Click view more button 15 time
# Click view more button 16 time
# Click view more button 17 time
# Click view more button 18 time
# Click view more button 19 time
# Click view more button 20 time
# Click view more reply 2 element
# 14
# Comment của Nguyen Kim Thuan này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đinh Văn Đức này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 1786546115010834
# Đang lấy thông tin của post có ID là 1780216588977120
# Click view more button 1 time
# Click view more reply 11 element
# Click view more reply 1 element
# 48
# Comment của Hiển Nguyễn này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Khang Duy Lê này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trần Hồng Phát này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Hữu Lịch này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Ryan Khan này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Việt Hoàng này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Neki Itou này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Dien Giau Bui này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Lê Bảo Bình này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Anh Khoa này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đức Thiện Trần này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 1778607179138061
# Click view more button 1 time
# Click view more reply 17 element
# Click view more reply 1 element
# 32
# Comment của Lê Hà này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hoàng Ngọc này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Thái Ngọc này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Hồng Giang này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Phạm Tùng Linh này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Lê Trung này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Dũng Trần này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Diệu Trịnh này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Minh Đức này có 6 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Kim Trung Tấn này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hoàng Quỳnh Trang này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyên Boon này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Lê Xuân Tuấn này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Cẩm Linh này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Vương Hoàng Ngâm này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Hoàng Thảo Quyên này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Lê Thanh Toàn này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 1783852401946872
# Đang lấy thông tin của post có ID là 1786546091677503
# Đang lấy thông tin của post có ID là 1786546071677505
# Đang lấy thông tin của post có ID là 1785840525081393
# Đang lấy thông tin của post có ID là 1785840548414724
# Đang lấy thông tin của post có ID là 1783852391946873
# Đang lấy thông tin của post có ID là 1786546085010837
# Đang lấy thông tin của post có ID là 1785138835151562
# Đang lấy thông tin của post có ID là 1786546055010840
# Đang lấy thông tin của post có ID là 1786615068337272
# 0
# Post này ko có comment :(
# Đang lấy thông tin của post có ID là 1786546098344169
# Đang lấy thông tin của post có ID là 1786546121677500
# Đang lấy thông tin của post có ID là 1786546118344167
# Đang lấy thông tin của post có ID là 1786546078344171
# Đang lấy thông tin của post có ID là 1786546081677504
# Đang lấy thông tin của post có ID là 1785840518414727
# Đang lấy thông tin của post có ID là 1784693011862811
# Đang lấy thông tin của post có ID là 1786080288390750
# Click view more reply 1 element
# 2
# Comment của Phố Đỗ Văn này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 1650103925321721
# Click view more button 1 time
# Click view more button 2 time
# Click view more button 3 time
# Click view more button 4 time
# Click view more button 5 time
# Click view more button 6 time
# Click view more button 7 time
# Click view more button 8 time
# Click view more button 9 time
# Click view more button 10 time
# Click view more button 11 time
# Click view more button 12 time
# Click view more button 13 time
# Click view more button 14 time
# Click view more button 15 time
# Click view more button 16 time
# Click view more button 17 time
# Click view more button 18 time
# Click view more button 19 time
# Click view more button 20 time
# Click view more reply 44 element
# Click view more reply 3 element
# 132
# Comment của Hoang Tran này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Văn Đoàn này có 5 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Loan Tô này có 6 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đinh Đức Thi này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Lê Quốc Bình này có 10 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Văn Hiệp này có 6 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hoang Tran này có 8 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trang Linh này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Việt Anh này có 5 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Mạnh Hùng này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hải Lưu này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Lâm Ngọc Khương này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Thắng này có 14 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Phương này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hoang Tran này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trực Phan này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Duy Lucas này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Cường Nguyễn này có 9 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Dương Tuấn Nhật này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Việt Thảo này có 7 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Minh Cảnh này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đặng Linh này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Vũ Đạt Phạm này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Phạm Vương Sơn này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Lê Huỳnh Hải Đăng này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Quang Minh này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trịnh Tú này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Erich Nguyễn này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Phạm Thành Nam này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Triệu Bảo này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Van Le này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Cẩm Ngọc này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đỗ Đức Hiệp này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Thắng Vương này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyên Em này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Vũ Quân này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Minh Thiện này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hoa Tú này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Dat D. Le này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Vũ Minh này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Sơn Thiên này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Chu Thế Anh này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Võ Kế Khoa này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hoang Tran này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 1785949375070508
# Click view more reply 5 element
# 17
# Comment của Nguyễn Bạc này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trần Tuấn Duy này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Lê Quỳnh này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Phạm Tuấn này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Alexander Nguyễn này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 1784693005196145
# Đang lấy thông tin của post có ID là 1785138815151564
# Đang lấy thông tin của post có ID là 655346384797485
# 0
# Post này ko có comment :(
# Đang lấy thông tin của post có ID là 489591794706279
# Click view more button 1 time
# Click view more button 2 time
# Click view more button 3 time
# Click view more button 4 time
# Click view more button 5 time
# Click view more button 6 time
# Click view more button 7 time
# Click view more button 8 time
# Click view more button 9 time
# Click view more button 10 time
# Click view more button 11 time
# Click view more button 12 time
# Click view more button 13 time
# Click view more button 14 time
# Click view more button 15 time
# Click view more button 16 time
# Click view more button 17 time
# Click view more button 18 time
# Click view more button 19 time
# Click view more button 20 time
# Click view more reply 18 element
# 295
# Post này ko có comment :(
# Đang lấy thông tin của post có ID là 1785138818484897
# Đang lấy thông tin của post có ID là 1775291399469639
# Click view more button 1 time
# Click view more button 2 time
# Click view more button 3 time
# Click view more button 4 time
# Click view more button 5 time
# Click view more button 6 time
# Click view more button 7 time
# Click view more button 8 time
# Click view more button 9 time
# Click view more button 10 time
# Click view more button 11 time
# Click view more button 12 time
# Click view more button 13 time
# Click view more button 14 time
# Click view more button 15 time
# Click view more button 16 time
# Click view more button 17 time
# Click view more button 18 time
# Click view more button 19 time
# Click view more button 20 time
# Click view more reply 46 element
# Click view more reply 3 element
# 103
# Comment của Nguyễn Quang Nhật Huy này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Văn Tiếnn Phạm này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Đức Bảo này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Mai Khoa này có 8 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đinh Văn Cảnh này có 11 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Truong Nguyen này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Mayonaka Kensaku này có 14 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hữu Phước này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Duy này có 5 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Ninh này có 5 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hoàng Võ này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Quỳnh Tâm này có 8 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nga Bùi này có 7 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Jolee Meubem này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Phí Mạnh Hùng này có 15 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đỗ Duy Hưng này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyen Anh này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hoàng Yến Nhi này có 7 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Thanh Tùng này có 16 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyeenx Quoocs Phus này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Lê Dương này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Phạm Hoàng Anh này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Luộc Đỗ này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Chinh này có 8 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Tâm này có 6 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Phạm Ngọc Nghĩa này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Chu Tuấn Anh này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hoàn Vũ này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Lại Tình này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Ha Hi này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đặng Tuấn Dương này có 7 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hadestrb này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Ngô Thanh Vân này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đào Đức Duy này có 5 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hồng Lu này có 8 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hoàng Vân Linh này có 8 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Xuân Thu này có 6 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trần Quốc Thịnh này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Minh Quoc này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hoàng Quốc Tuấn này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trần Khang An này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trần Minh Đạt này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Phương Anh này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Hoàng này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Hoà Nghĩa này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 1785670301765082
# Click view more button 1 time
# Click view more button 2 time
# Click view more button 3 time
# Click view more button 4 time
# Click view more button 5 time
# Click view more button 6 time
# Click view more button 7 time
# Click view more button 8 time
# Click view more button 9 time
# Click view more button 10 time
# Click view more button 11 time
# Click view more button 12 time
# Click view more button 13 time
# Click view more button 14 time
# Click view more button 15 time
# Click view more button 16 time
# Click view more button 17 time
# Click view more button 18 time
# Click view more button 19 time
# Click view more button 20 time
# Click view more reply 18 element
# 97
# Comment của Namm Trườngg này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Khánh Phan này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Lưu Giang này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Tr Nguyen Phuong Anh này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của
có 5 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hai Dinh Ha này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Thành Khải này có 7 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Mai Thị Vanh này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Do Ngoc Anh này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Quốc Việt Nguyễn này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đỗ Xuân Trường này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Vũ Văn Hoàn này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Phat Phat này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Khánh Nguyễn Quốc này có 10 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trần Nho Đức này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Thành Lộc này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Kiều Trân này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Duyen Anh này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hiếu này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Bùi Gia Bảo này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyen Quang này có 10 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đoàn Duy Thành này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Chí Toản này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trần Danh này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Hữu Đạt này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Tùng Còi này có 9 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đức này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hai Dinh Ha này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Tuan Nam này có 5 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đoàn Mạnh Chiến này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Lê Thịnh này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Thảo Nguyên này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Minh Tiến này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Anh Hào này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trịnh Văn Quân này có 5 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Lê HậU này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Tuấn Phan Văn này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Gia Bảo này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Ngọc Hiếu này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Tai VT này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Bùi Hiệp này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Ngô Đình Vũ này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Bùi Quang Độ này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nghĩa này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hoà này có 8 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Minh Đức này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Phan Vĩnh Hải này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Ngô Văn Chương này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trương Văn Ngọc này có 16 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Thành Đức Nguyễn này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Anh Minh này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Minh Trương này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đặng Đình Anh này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Linh Hạ này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trần Tuấn Minh này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Linh Khánh Ngô Thị này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Anh Nhân này có 11 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Văn Lịch này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Danh này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hoàng Hải Long này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trương Thiên Định này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Pham Anh này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Huỳnh Thiên Vũ này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hồng Phúc Hải này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của HÀ DƯƠNG này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Lý Đắc Vinh này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Rin Nguyễn này có 5 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Jaycee Nguyen này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Linh này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyen Thanh Son này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Công Tô Chính này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Võ Phạm Hữu Tuấn này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Xuân Vinh Hồ này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Sơn này có 7 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 1785138865151559
# Click view more reply 1 element
# 2
# Comment của Mi HaMi này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 1785840588414720
# Đang lấy thông tin của post có ID là 1785840571748055
# Đang lấy thông tin của post có ID là 1785840551748057
# Đang lấy thông tin của post có ID là 1785840601748052
# Đang lấy thông tin của post có ID là 1785840511748061
# Click view more reply 1 element
# 5
# Comment của Thượng Khoa này có 8 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 1783669645298481
# Click view more button 1 time
# Click view more button 2 time
# Click view more button 3 time
# Click view more button 4 time
# Click view more button 5 time
# Click view more button 6 time
# Click view more button 7 time
# Click view more button 8 time
# Click view more button 9 time
# Click view more button 10 time
# Click view more button 11 time
# Click view more button 12 time
# Click view more button 13 time
# Click view more button 14 time
# Click view more button 15 time
# Click view more button 16 time
# Click view more button 17 time
# Click view more button 18 time
# Click view more button 19 time
# Click view more button 20 time
# Click view more reply 11 element
# 57
# Comment của Nguyễn Duy Khang này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Hoàng này có 6 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hoàng Nhật này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Thiện này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Zack Lee này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Lương Thế Vỹ này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Nhan Gia Bảo này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hoàng Hương này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Mạnh này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Văn Dũng này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 1593361297662651
# Click view more button 1 time
# Click view more button 2 time
# Click view more button 3 time
# Click view more button 4 time
# Click view more button 5 time
# Click view more button 6 time
# Click view more button 7 time
# Click view more button 8 time
# Click view more button 9 time
# Click view more button 10 time
# Click view more button 11 time
# Click view more button 12 time
# Click view more button 13 time
# Click view more button 14 time
# Click view more button 15 time
# Click view more button 16 time
# Click view more button 17 time
# Click view more button 18 time
# Click view more button 19 time
# Click view more button 20 time
# Click view more reply 110 element
# Click view more reply 10 element
# 237
# Comment của Duc Manh này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Trang này có 8 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Phúc Thiện này có 7 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyen Anh này có 7 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Chu Đức Phúc này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Võ Trung Quân này có 12 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Huy Kyo này có 11 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trương Nguyễn Thế Huy này có 8 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyen Anh này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hiếu Chu này có 6 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Phạm Trực này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyen Van Khang này có 6 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Việt Anh này có 5 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Thảo Trang này có 8 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Quốc Bảo này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Anh Tú Nguyễn này có 17 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Tuân Nguyễn này có 8 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Thắng Lợi này có 7 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Tấn Tài này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Thế Phong này có 14 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hadestrb này có 5 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Thương Duy này có 7 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Phương Linh Đào này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Sơn Thiên này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Tiến Rocket này có 7 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Tèo Trọng này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đỗ Kim Sâu này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đặng Quang Huy này có 11 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hiếu này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hạnh Đoàn này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Võ Trọng Dũng này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Bùi Vũ Duy này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Cường Quốc Phạm này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nam Hoàng này có 5 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Ngô Quang Thơm này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Minh Thiên Thanh này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Lê Tùng Thiện này có 4 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trần Trọng Nghĩa này có 5 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của
# Đang lấy thông tin của post có ID là 1769613426704103
# Đang lấy thông tin của post có ID là 1500326780299437
# Đang lấy thông tin của post có ID là 1769800423352070
# Đang lấy thông tin của post có ID là 1722077884790991
# Đang lấy thông tin của post có ID là 1769613503370762
# Đang lấy thông tin của post có ID là 1769613403370772
# Đang lấy thông tin của post có ID là 1769613463370766
# Đang lấy thông tin của post có ID là 1768469166818529
# Đang lấy thông tin của post có ID là 1768841540114625
# Đang lấy thông tin của post có ID là 1187880451544073
# Đang lấy thông tin của post có ID là 1748545992144180
# Đang lấy thông tin của post có ID là 1769613523370760
# Đang lấy thông tin của post có ID là 1767438486921597
# Đang lấy thông tin của post có ID là 1769613486704097
# Đang lấy thông tin của post có ID là 1769613466704099
# Đang lấy thông tin của post có ID là 1769613443370768
# Đang lấy thông tin của post có ID là 1767856510213128
# Đang lấy thông tin của post có ID là 1768537510145028
# Đang lấy thông tin của post có ID là 1769613410037438
# Đang lấy thông tin của post có ID là 1769613483370764
# Đang lấy thông tin của post có ID là 1321260668206050
# Đang lấy thông tin của post có ID là 1769613413370771
# Đang lấy thông tin của post có ID là 1769613436704102
# Đang lấy thông tin của post có ID là 1762872247378221
# Đang lấy thông tin của post có ID là 831474427184679
# Đang lấy thông tin của post có ID là 1767726236892822
# Đang lấy thông tin của post có ID là 1769613456704100
# Đang lấy thông tin của post có ID là 1769613460037433
# Đang lấy thông tin của post có ID là 1761265167538929
# Đang lấy thông tin của post có ID là 1768498490148930
# Đang lấy thông tin của post có ID là 1768419196823526
# Đang lấy thông tin của post có ID là 1721939624804817
# Đang lấy thông tin của post có ID là 1769613526704093
# Đang lấy thông tin của post có ID là 1768477283484384
# Đang lấy thông tin của post có ID là 1769613513370761
# Đang lấy thông tin của post có ID là 1769613416704104
# Đang lấy thông tin của post có ID là 1765316480467131
# Đang lấy thông tin của post có ID là 1769613473370765
# Đang lấy thông tin của post có ID là 1766901720308607
# Đang lấy thông tin của post có ID là 797259323939523
# Đang lấy thông tin của post có ID là 1766955916969854
# Đang lấy thông tin của post có ID là 1769613450037434
# Đang lấy thông tin của post có ID là 1769613536704092
# Success
# Srolling 0 time
# Srolling 1 time
# Srolling 2 time
# Srolling 3 time
# Srolling 4 time
# Srolling 5 time
# Srolling 6 time
# Srolling 7 time
# Srolling 8 time
# Srolling 9 time
# Srolling 10 time
# Srolling 11 time
# Srolling 12 time
# Srolling 13 time
# Srolling 14 time
# Srolling 15 time
# Srolling 16 time
# Srolling 17 time
# Srolling 18 time
# Srolling 19 time
# Srolling 20 time
# Srolling 21 time
# Srolling 22 time
# Srolling 23 time
# Srolling 24 time
# Srolling 25 time
# Srolling 26 time
# Srolling 27 time
# Srolling 28 time
# Srolling 29 time
# Srolling 30 time
# Srolling 31 time
# Srolling 32 time
# Srolling 33 time
# Srolling 34 time
# Srolling 35 time
# Srolling 36 time
# Srolling 37 time
# Srolling 38 time
# Srolling 39 time
# Srolling 40 time
# Srolling 41 time
# Srolling 42 time
# Srolling 43 time
# Srolling 44 time
# Srolling 45 time
# Srolling 46 time
# Srolling 47 time
# Srolling 48 time
# Srolling 49 time
# Srolling 50 time
# Srolling 51 time
# Success
# Srolling 0 time
# Srolling 1 time
# Srolling 2 time
# Srolling 3 time
# Srolling 4 time
# Srolling 5 time
# Srolling 6 time
# Srolling 7 time
# Srolling 8 time
# Srolling 9 time
# Srolling 10 time
# Srolling 11 time
# Srolling 12 time
# Srolling 13 time
# Srolling 14 time
# Srolling 15 time
# Srolling 16 time
# Srolling 17 time
# Srolling 18 time
# Srolling 19 time
# Srolling 20 time
# Srolling 21 time
# Srolling 22 time
# Srolling 23 time
# Srolling 24 time
# Srolling 25 time
# Srolling 26 time
# Srolling 27 time
# Srolling 28 time
# Srolling 29 time
# Srolling 30 time
# Srolling 31 time
# Srolling 32 time
# Srolling 33 time
# Srolling 34 time
# Srolling 35 time
# Srolling 36 time
# Srolling 37 time
# Srolling 38 time
# Srolling 39 time
# Srolling 40 time
# Srolling 41 time
# Srolling 42 time
# Srolling 43 time
# Srolling 44 time
# Srolling 45 time
# Srolling 46 time
# Srolling 47 time
# Srolling 48 time
# Srolling 49 time
# Srolling 50 time
# Srolling 51 time
# Success
# Srolling 0 time
# Srolling 1 time
# Srolling 2 time
# Srolling 3 time
# Srolling 4 time
# Srolling 5 time
# Srolling 6 time
# Srolling 7 time
# Srolling 8 time
# Srolling 9 time
# Srolling 10 time
# Srolling 11 time
# Srolling 12 time
# Srolling 13 time
# Srolling 14 time
# Srolling 15 time
# Srolling 16 time
# Srolling 17 time
# Srolling 18 time
# Srolling 19 time
# Srolling 20 time
# Srolling 21 time
# Srolling 22 time
# Srolling 23 time
# Srolling 24 time
# Srolling 25 time
# Srolling 26 time
# Srolling 27 time
# Srolling 28 time
# Srolling 29 time
# Srolling 30 time
# Srolling 31 time
# Srolling 32 time
# Srolling 33 time
# Srolling 34 time
# Srolling 35 time
# Srolling 36 time
# Srolling 37 time
# Srolling 38 time
# Srolling 39 time
# Srolling 40 time
# Srolling 41 time
# Srolling 42 time
# Srolling 43 time
# Srolling 44 time
# Srolling 45 time
# Srolling 46 time
# Srolling 47 time
# Srolling 48 time
# Srolling 49 time
# Srolling 50 time
# Srolling 51 time
# Success
# Srolling 0 time
# Srolling 1 time
# Srolling 2 time
# Srolling 3 time
# Srolling 4 time
# Srolling 5 time
# Srolling 6 time
# Srolling 7 time
# Srolling 8 time
# Srolling 9 time
# Srolling 10 time
# Srolling 11 time
# Srolling 12 time
# Srolling 13 time
# Srolling 14 time
# Srolling 15 time
# Srolling 16 time
# Srolling 17 time
# Srolling 18 time
# Srolling 19 time
# Srolling 20 time
# Srolling 21 time
# Srolling 22 time
# Srolling 23 time
# Srolling 24 time
# Srolling 25 time
# Srolling 26 time
# Srolling 27 time
# Srolling 28 time
# Srolling 29 time
# Srolling 30 time
# Srolling 31 time
# Srolling 32 time
# Srolling 33 time
# Srolling 34 time
# Srolling 35 time
# Srolling 36 time
# Srolling 37 time
# Srolling 38 time
# Srolling 39 time
# Srolling 40 time
# Srolling 41 time
# Srolling 42 time
# Srolling 43 time
# Srolling 44 time
# Srolling 45 time
# Srolling 46 time
# Srolling 47 time
# Srolling 48 time
# Srolling 49 time
# Srolling 50 time
# Srolling 51 time
# Success
# Srolling 0 time
# Srolling 1 time
# Srolling 2 time
# Srolling 3 time
# Srolling 4 time
# Srolling 5 time
# Srolling 6 time
# Srolling 7 time
# Srolling 8 time
# Srolling 9 time
# Srolling 10 time
# Srolling 11 time
# Srolling 12 time
# Srolling 13 time
# Srolling 14 time
# Srolling 15 time
# Srolling 16 time
# Srolling 17 time
# Srolling 18 time
# Srolling 19 time
# Srolling 20 time
# Srolling 21 time
# Srolling 22 time
# Srolling 23 time
# Srolling 24 time
# Srolling 25 time
# Srolling 26 time
# Srolling 27 time
# Srolling 28 time
# Srolling 29 time
# Srolling 30 time
# Srolling 31 time
# Srolling 32 time
# Srolling 33 time
# Srolling 34 time
# Srolling 35 time
# Srolling 36 time
# Srolling 37 time
# Srolling 38 time
# Srolling 39 time
# Srolling 40 time
# Srolling 41 time
# Srolling 42 time
# Srolling 43 time
# Srolling 44 time
# Srolling 45 time
# Srolling 46 time
# Srolling 47 time
# Srolling 48 time
# Srolling 49 time
# Srolling 50 time
# Srolling 51 time
# Success
# Srolling 0 time
# Srolling 1 time
# Srolling 2 time
# Srolling 3 time
# Srolling 4 time
# Srolling 5 time
# Srolling 6 time
# Srolling 7 time
# Srolling 8 time
# Srolling 9 time
# Srolling 10 time
# Srolling 11 time
# Srolling 12 time
# Srolling 13 time
# Srolling 14 time
# Srolling 15 time
# Srolling 16 time
# Srolling 17 time
# Srolling 18 time
# Srolling 19 time
# Srolling 20 time
# Srolling 21 time
# Srolling 22 time
# Srolling 23 time
# Srolling 24 time
# Srolling 25 time
# Srolling 26 time
# Srolling 27 time
# Srolling 28 time
# Srolling 29 time
# Srolling 30 time
# Srolling 31 time
# Srolling 32 time
# Srolling 33 time
# Srolling 34 time
# Srolling 35 time
# Srolling 36 time
# Srolling 37 time
# Srolling 38 time
# Srolling 39 time
# Srolling 40 time
# Srolling 41 time
# Srolling 42 time
# Srolling 43 time
# Srolling 44 time
# Srolling 45 time
# Srolling 46 time
# Srolling 47 time
# Srolling 48 time
# Srolling 49 time
# Srolling 50 time
# Srolling 51 time
# Success
# Srolling 0 time
# Srolling 1 time
# Srolling 2 time
# Srolling 3 time
# Srolling 4 time
# Srolling 5 time
# Srolling 6 time
# Srolling 7 time
# Srolling 8 time
# Srolling 9 time
# Srolling 10 time
# Srolling 11 time
# Srolling 12 time
# Srolling 13 time
# Srolling 14 time
# Srolling 15 time
# Srolling 16 time
# Srolling 17 time
# Srolling 18 time
# Srolling 19 time
# Srolling 20 time
# Srolling 21 time
# Srolling 22 time
# Srolling 23 time
# Srolling 24 time
# Srolling 25 time
# Srolling 26 time
# Srolling 27 time
# Srolling 28 time
# Srolling 29 time
# Srolling 30 time
# Srolling 31 time
# Srolling 32 time
# Srolling 33 time
# Srolling 34 time
# Srolling 35 time
# Srolling 36 time
# Srolling 37 time
# Srolling 38 time
# Srolling 39 time
# Srolling 40 time
# Srolling 41 time
# Srolling 42 time
# Srolling 43 time
# Srolling 44 time
# Srolling 45 time
# Srolling 46 time
# Srolling 47 time
# Srolling 48 time
# Srolling 49 time
# Srolling 50 time
# Srolling 51 time
# Success
# Srolling 0 time
# Srolling 1 time
# Srolling 2 time
# Srolling 3 time
# Srolling 4 time
# Srolling 5 time
# Srolling 6 time
# Srolling 7 time
# Srolling 8 time
# Srolling 9 time
# Srolling 10 time
# Srolling 11 time
# Srolling 12 time
# Srolling 13 time
# Srolling 14 time
# Srolling 15 time
# Srolling 16 time
# Srolling 17 time
# Srolling 18 time
# Srolling 19 time
# Srolling 20 time
# Srolling 21 time
# Srolling 22 time
# Srolling 23 time
# Srolling 24 time
# Srolling 25 time
# Srolling 26 time
# Srolling 27 time
# Srolling 28 time
# Srolling 29 time
# Srolling 30 time
# Srolling 31 time
# Srolling 32 time
# Srolling 33 time
# Srolling 34 time
# Srolling 35 time
# Srolling 36 time
# Srolling 37 time
# Srolling 38 time
# Srolling 39 time
# Srolling 40 time
# Srolling 41 time
# Srolling 42 time
# Srolling 43 time
# Srolling 44 time
# Srolling 45 time
# Srolling 46 time
# Srolling 47 time
# Srolling 48 time
# Srolling 49 time
# Srolling 50 time
# Srolling 51 time
# Success
# Srolling 0 time
# Srolling 1 time
# Srolling 2 time
# Srolling 3 time
# Srolling 4 time
# Srolling 5 time
# Srolling 6 time
# Srolling 7 time
# Srolling 8 time
# Srolling 9 time
# Srolling 10 time
# Srolling 11 time
# Srolling 12 time
# Srolling 13 time
# Srolling 14 time
# Srolling 15 time
# Srolling 16 time
# Srolling 17 time
# Srolling 18 time
# Srolling 19 time
# Srolling 20 time
# Srolling 21 time
# Srolling 22 time
# Srolling 23 time
# Srolling 24 time
# Srolling 25 time
# Srolling 26 time
# Srolling 27 time
# Srolling 28 time
# Srolling 29 time
# Srolling 30 time
# Srolling 31 time
# Srolling 32 time
# Srolling 33 time
# Srolling 34 time
# Srolling 35 time
# Srolling 36 time
# Srolling 37 time
# Srolling 38 time
# Srolling 39 time
# Srolling 40 time
# Srolling 41 time
# Srolling 42 time
# Srolling 43 time
# Srolling 44 time
# Srolling 45 time
# Srolling 46 time
# Srolling 47 time
# Srolling 48 time
# Srolling 49 time
# Srolling 50 time
# Srolling 51 time
# Success
