# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# %load_ext autoreload
# %autoreload 1

# %%
from test import *
# from importlib.resources import contents
# from pip import main
import os
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
import os
from time import sleep
import json 

# list file post
import glob
groupPost = glob.glob("rawData/*/*/*.json")
pagePost = glob.glob("rawData/*/*.json")
groupPagePost = groupPost + pagePost
listPostFile = []
for postFile in groupPagePost:
    listPostFile.append(postFile.split("\\")[-1].split(".")[0])

# cookie = 'cookie: datr=zCl1YfSOcGf17m9dXXY7eSaB; sb=zg8HYr27z2Eze4zpOblULwod; dpr=1.25; locale=vi_VN; wd=1488x754; c_user=100078509210570; xs=2%3AdK7lsdMi8XwFoQ%3A2%3A1646105133%3A-1%3A-1; fr=0MRspGNSQYfr6Brep.AWWETuMAYWgC08UmlQDDNmoo6UM.BiHNcs.jK.AAA.0.0.BiHZJM.AWXjlK0yd7A; presence=C%7B%22t3%22%3A%5B%5D%2C%22utc3%22%3A1646105170400%2C%22v%22%3A1%7D'
driver = initDriver(headless=False, usingProfile=True)
# driver = loadExtensionVPN(driver)
# sleep(5)

namePage = [
  'groups/364997627165697',
  'nhung.truyen.ngan.hay',
  'danphunhuantphcm', 
  'nhatky',
  'vntravel',
  'rapphim',
  'KHTNCFS',
  'CodeLearnFanpage',
  'pagenaykhonghetrend',
  'chuyencuaem.page'
  ]

# sleep(2)
# driver = loginFacebook(driver)
# loginFacebookByCookie(driver ,cookie)
sleep(4)
print("start crawl")
for page in namePage:
  try:
      dsPost = {}
      Id_List = getnumOfPost(driver, page)
      if not os.path.exists(f'rawData/{page}'):
        os.makedirs(f'rawData/{page}')
      for idPost in Id_List:
        if (idPost in listPostFile):
          continue
        DS = getPoster(driver, idPost)
        if DS is not None:
          with open(f'rawData/{page}/{idPost}.json', "w",encoding="utf-8") as outfile:
            json.dump(DS, outfile, ensure_ascii=False)
        # dsPost[str(idPost)]= DS
      print('Success')
  except Exception as e:
    print('Failed')
    print(e)
driver.close()
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
# start crawl
# Srolling 0 time
# Srolling 1 time
# Đang lấy thông tin của post có ID là 1793266151005497
# Click view more button 1 time
# Không có bình luận cần tải thêm
# Click view more reply 13 element
# Click view more reply 7 element
# Click view more reply 5 element
# Click view more reply 4 element
# 49
# Comment của Phạm Tuấn này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Le Kiet này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Bảo Phúc này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Thanh Phong này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Minh Hùng này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Lê Hiệu này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Bạn Đạt Giấu Tên này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Văn Lập này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Phạm Hoàng này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Quốc Việt này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Khải Minh này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Kydra Long này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Tiến Đạt này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 1792680121064100
# Không có bình luận cần tải thêm
# Click view more reply 2 element
# 5
# Comment của Công Thành này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Jason Nguyen này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 1792615114403934
# Post không có media
# Click view more button 1 time
# Click view more button 2 time
# Click view more button 3 time
# Không có bình luận cần tải thêm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-7a9fa91054d3> in <module>
#      51         if (idPost in listPostFile):
#      52           continue
# ---> 53         DS = getPoster(driver, idPost)
#      54         if DS is not None:
#      55           with open(f'data/{page}/{idPost}.json', "w",encoding="utf-8") as outfile:
#
# f:\Learning\Research\2021-2022\facebook-data-extraction\2 - Automation tools with IP hiding techniques\test.py in getPoster(driver, postId)
#     308                     try:
#     309                         # print(x.text)
# --> 310                         x.click()
#     311                     except Exception as e:
#     312                         pass
#
# ~\anaconda3\envs\auto\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda3\envs\auto\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\envs\auto\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\anaconda3\envs\auto\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\anaconda3\envs\auto\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\anaconda3\envs\auto\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      77         else:
#      78             return self.request_encode_body(
# ---> 79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#      81
#
# ~\anaconda3\envs\auto\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# ~\anaconda3\envs\auto\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     373             response = conn.urlopen(method, url, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#     377         redirect_location = redirect and response.get_redirect_location()
#
# ~\anaconda3\envs\auto\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     708                 body=body,
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#     712
#
# ~\anaconda3\envs\auto\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\envs\auto\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\envs\auto\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\envs\auto\lib\http\client.py in getresponse(self)
#    1377         try:
#    1378             try:
# -> 1379                 response.begin()
#    1380             except ConnectionError:
#    1381                 self.close()
#
# ~\anaconda3\envs\auto\lib\http\client.py in begin(self)
#     309         # read until we get a non-100 response
#     310         while True:
# --> 311             version, status, reason = self._read_status()
#     312             if status != CONTINUE:
#     313                 break
#
# ~\anaconda3\envs\auto\lib\http\client.py in _read_status(self)
#     270
#     271     def _read_status(self):
# --> 272         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     273         if len(line) > _MAXLINE:
#     274             raise LineTooLong("status line")
#
# ~\anaconda3\envs\auto\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import datetime
conversion = datetime.datetime.fromtimestamp(1646534522)
print(conversion)
# Out:
# 2022-03-06 09:42:02
