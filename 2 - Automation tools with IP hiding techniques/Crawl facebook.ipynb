# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from test import *
# from importlib.resources import contents
from pip import main
import os
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
import os
from time import sleep
import json 
cookie = 'cookie: datr=zCl1YfSOcGf17m9dXXY7eSaB; sb=zg8HYr27z2Eze4zpOblULwod; dpr=1.25; locale=vi_VN; wd=1488x754; c_user=100078509210570; xs=2%3AdK7lsdMi8XwFoQ%3A2%3A1646105133%3A-1%3A-1; fr=0MRspGNSQYfr6Brep.AWWETuMAYWgC08UmlQDDNmoo6UM.BiHNcs.jK.AAA.0.0.BiHZJM.AWXjlK0yd7A; presence=C%7B%22t3%22%3A%5B%5D%2C%22utc3%22%3A1646105170400%2C%22v%22%3A1%7D'
driver = initDriver()
# driver.get('https://touch.facebook.com/')

namePage = 'danphunhuantphcm'

# sleep(2)
driver = loginFacebook(driver)
# loginFacebookByCookie(driver ,cookie)
sleep(4)
print("start crawl")
try:
    dsPost={}
    Id_List = getnumOfPost(driver, namePage)
    if not os.path.exists(f'data/{namePage}'):
      os.makedirs(f'data/{namePage}')
    for idPost in Id_List:
      DS = getPoster(driver, idPost)
      with open(f'data/{namePage}/{idPost}.json', "w",encoding="utf-8") as outfile:
        json.dump(DS, outfile, ensure_ascii=False)
      # dsPost[str(idPost)]= DS
    print('Success')
except Exception as e:
  print('Failed')
  print(e)
driver.close()
# Out:
# phong940256@gmail.com
# start crawl
# Srolling 0 time
# Srolling 1 time
# Srolling 2 time
# Srolling 3 time
# Srolling 4 time
# Srolling 5 time
# Đang lấy thông tin của post có ID là 521198422755201
# Hoàng Nguyễn đã trả lời · 1 người trả lời
# Click view more reply 1 element
# 4
# Comment của Đức Đu Đủ này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 521085786099798
# Trang Thuy đã trả lời · 1 người trả lời
# Nguyễn Hồng Kông đã trả lời · 2 phản hồi
# Hong Trinh đã trả lời · 1 người trả lời
# Hoàng Minh đã trả lời · 2 phản hồi
# Click view more reply 4 element
# 17
# Comment của Nguyễn Hồng Kông này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trần Nguyễn Bá Kim Long này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Po Po này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 521012629440447
# Đang lấy thông tin của post có ID là 521002939441416
# Trần Thành Tài đã trả lời · 1 người trả lời
# Hoàng Nguyễn đã trả lời · 1 người trả lời
# Lê Thuận Vũ đã trả lời · 6 phản hồi
# Lý Duy Mạnh đã trả lời · 2 phản hồi
# Click view more reply 4 element
# 18
# Comment của Dăn Đông này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Cong Danh Pham này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Lê Thuận Vũ này có 6 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hân Hân này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 520957479445962
# Đang lấy thông tin của post có ID là 520946129447097
# Đang lấy thông tin của post có ID là 520876239454086
# Đang lấy thông tin của post có ID là 520866346121742
# Đang lấy thông tin của post có ID là 520831776125199
# Đang lấy thông tin của post có ID là 520543776153999
# Đang lấy thông tin của post có ID là 520543006154076
# Đang lấy thông tin của post có ID là 520520756156301
# Đang lấy thông tin của post có ID là 520500452824998
# Click view more button 1 time
# Click view more button 2 time
# Click view more button 3 time
# Click view more button 4 time
# Click view more button 5 time
# Click view more button 6 time
# Click view more button 7 time
# Click view more button 8 time
# Click view more button 9 time
# Click view more button 10 time
# Click view more button 11 time
# Click view more button 12 time
# Click view more button 13 time
# Click view more button 14 time
# Click view more button 15 time
# Click view more button 16 time
# Click view more button 17 time
# Click view more button 18 time
# Click view more button 19 time
# Click view more button 20 time
# Quynh Duong đã trả lời · 2 phản hồi
# Gia Lâm đã trả lời · 1 người trả lời
# Thảo Nguyễn đã trả lời · 1 người trả lời
# Trần Nguyễn Ma... đã trả lời · 1 người trả lời
# Trương Trân đã trả lời · 1 người trả lời
# TQ Dũng đã trả lời · 2 phản hồi
# Nguyễn Yến đã trả lời · 1 người trả lời
# Bé Gấu MiSa đã trả lời · 9 phản hồi
# Vân Hồng đã trả lời · 1 người trả lời
# Thanh Tac đã trả lời · 1 người trả lời
# Thu Nguyên đã trả lời · 1 người trả lời
# Hoàng Vinh Nghĩa đã trả lời · 1 người trả lời
# Don Quijote đã trả lời · 1 người trả lời
# Minh Nhật đã trả lời · 3 phản hồi
# Trong Anh đã trả lời · 1 người trả lời
# Đặng Quốc Khánh đã trả lời · 1 người trả lời
# Bảo Vy đã trả lời · 2 phản hồi
# Nghi Chau đã trả lời · 1 người trả lời
# Bảo Trânn đã trả lời · 1 người trả lời
# Kim Xuyến đã trả lời · 2 phản hồi
# Đào Thanh Hiền đã trả lời · 2 phản hồi
# Thanh Thao đã trả lời · 2 phản hồi
# Phạm Văn Bảo đã trả lời · 1 người trả lời
# Hằng Thị Mai đã trả lời · 1 người trả lời
# Thu Ngân đã trả lời · 3 phản hồi
# Mỹ Duyên đã trả lời · 1 người trả lời
# huỳnh mai đã trả lời · 1 người trả lời
# Mưa Cát Bụi đã trả lời · 1 người trả lời
# Phương Lan Trần đã trả lời · 2 phản hồi
# Anny Nguyen đã trả lời · 1 người trả lời
# Đức Đoàn đã trả lời · 5 phản hồi
# Cao Thái Thuỷ... đã trả lời · 1 người trả lời
# Click view more reply 32 element
# Thanh Thao đã trả lời · 2 phản hồi
# huỳnh mai đã trả lời · 1 người trả lời
# Click view more reply 2 element
# 49
# Comment của Quynh Duong này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nga Le này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của DuyThanh Ha này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Thuỷ Trúc này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Toan Nguyen này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Fan cứng
# TQ Dũng này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Fan cứng
# Tham Tran này có 9 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Trang Lê này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Mythao Luong này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Tra My này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Chi Lì này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Fan cứng
# Nguyễn Bảo Thiên này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Minh Nhật này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Phạm Lệ này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Ngọc Thanh này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Bảo Vy này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Ngân Moon này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Khương Trần này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Kim Xuyến này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đào Thanh Hiền này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Thanh Thao này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Trúc Đào này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Võ Ngọc Sương này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Thi Trần này có 3 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đặng Tuyết Dâng này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Đinh Thị Tuyết Vân này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Giang này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Thịnh Râu này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Ngọc Tường Vân này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hồ Yến Ngọc này có 5 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Ngọc Bảo Trân này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 520469629494747
# Đang lấy thông tin của post có ID là 520360922838951
# Ghẹ Rang Panna... đã trả lời · 1 người trả lời
# Click view more reply 1 element
# 2
# Comment của Bang Banglang này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 520335132841530
# 1
# Đang lấy thông tin của post có ID là 520315292843514
# Đang lấy thông tin của post có ID là 520302959511414
# Đang lấy thông tin của post có ID là 520260922848951
# Đang lấy thông tin của post có ID là 520225342852509
# Ngọc Bích đã trả lời · 1 người trả lời
# nguyễn kim anh đã trả lời · 2 phản hồi
# Cong Duong đã trả lời · 5 phản hồi
# Uyen Nguyen đã trả lời · 1 người trả lời
# Nguyễn Thanh Thư đã trả lời · 1 người trả lời
# Khánh An đã trả lời · 1 người trả lời
# Click view more reply 6 element
# 23
# Comment của Tna Thy này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của nguyễn kim anh này có 2 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Phạm Thành Trung này có 5 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Hải Vân này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Nguyễn Cao Thanh Nhật này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Comment của Kim Vy này có 1 reply
# Đang lấy reply...
# Đã lấy xong reply :)
# Đang lấy thông tin của post có ID là 520207709520939
# Đang lấy thông tin của post có ID là 520187589522951
# Đang lấy thông tin của post có ID là 520164872858556
# Đang lấy thông tin của post có ID là 106133404261707
# Success
